-- %%
GRANT USE CATALOG ON CATALOG policyiq TO `******`;
GRANT USE SCHEMA ON SCHEMA policyiq.silver TO `*****`;
GRANT USE SCHEMA ON SCHEMA policyiq.bronze TO `*****`;
GRANT USE SCHEMA ON SCHEMA policyiq.gold TO `*****`;

GRANT SELECT ON TABLE policyiq.silver.kpi_compliance_facts TO `*****`;
GRANT SELECT ON TABLE policyiq.bronze.branch_dim TO `*****`;
GRANT SELECT ON TABLE policyiq.bronze.policy_registry TO `******`;
GRANT SELECT ON TABLE policyiq.bronze.kpi_registry TO `******`;


GRANT SELECT ON TABLE policyiq.silver.policy_chunks_index TO `******`;
GRANT SELECT ON TABLE policyiq.silver.policy_chunks TO `*******`;
GRANT EXECUTE ON FUNCTION policyiq.gold.search_policy_text TO `******`;
